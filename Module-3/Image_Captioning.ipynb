# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import keras
import json
import pickle
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input, decode_predictions
from keras.preprocessing import image
from tensorflow.keras.models import load_model

from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Dense, Dropout, Embedding, LSTM
from tensorflow.keras.layers import Add
#for voice
from playsound import playsound
from gtts import gTTS 
import os 
import time

# %%
BASE_DIR = os.getcwd()

model_path = os.path.join(BASE_DIR, "Model_Weights", "model_8.h5")

model = load_model(model_path)
model.make_predict_function()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 5
#       1 BASE_DIR = os.getcwd()
#       3 model_path = os.path.join(BASE_DIR, "Model_Weights", "model_8.h5")
# ----> 5 model = load_model(model_path)
#       6 model.make_predict_function()
#
# File ~/project/venv/lib/python3.11/site-packages/keras/src/saving/saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath,
#     198         custom_objects=custom_objects,
#     199         compile=compile,
#     200         safe_mode=safe_mode,
#     201     )
#     202 elif str(filepath).endswith(".keras"):
#     203     raise ValueError(
#     204         f"File not found: filepath={filepath}. "
#     205         "Please ensure the file is an accessible `.keras` "
#     206         "zip file."
#     207     )
#
# File ~/project/venv/lib/python3.11/site-packages/keras/src/legacy/saving/legacy_h5_format.py:137, in load_model_from_hdf5(filepath, custom_objects, compile, safe_mode)
#     135 safe_mode_scope = serialization_lib.SafeModeScope(safe_mode)
#     136 with legacy_scope, safe_mode_scope:
# --> 137     model = saving_utils.model_from_config(
#     138         model_config, custom_objects=custom_objects
#     139     )
#     141     # set weights
#     142     load_weights_from_hdf5_group(f["model_weights"], model)
#
# File ~/project/venv/lib/python3.11/site-packages/keras/src/legacy/saving/saving_utils.py:83, in model_from_config(config, custom_objects)
#      80         function_dict["config"]["closure"] = function_config[2]
#      81         config["config"]["function"] = function_dict
# ---> 83 return serialization.deserialize_keras_object(
#      84     config,
#      85     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      86     custom_objects=custom_objects,
#      87     printable_module_name="layer",
#      88 )
#
# File ~/project/venv/lib/python3.11/site-packages/keras/src/legacy/saving/serialization.py:488, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     485 custom_objects = custom_objects or {}
#     487 if "custom_objects" in arg_spec.args:
# --> 488     deserialized_obj = cls.from_config(
#     489         cls_config,
#     490         custom_objects={
#     491             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     492             **custom_objects,
#     493         },
#     494     )
#     495 else:
#     496     with object_registration.CustomObjectScope(custom_objects):
#
# File ~/project/venv/lib/python3.11/site-packages/keras/src/models/model.py:823, in Model.from_config(cls, config, custom_objects)
#     818 if is_functional_config and revivable_as_functional:
#     819     # Revive Functional model
#     820     # (but not Functional subclasses with a custom __init__)
#     821     from keras.src.models.functional import functional_from_config
# --> 823     return functional_from_config(
#     824         cls, config, custom_objects=custom_objects
#     825     )
#     827 # Either the model has a custom __init__, or the config
#     828 # does not contain all the information necessary to
#     829 # revive a Functional model. This happens when the user creates
#    (...)    832 # In this case, we fall back to provide all config into the
#     833 # constructor of the class.
#     834 try:
#
# File ~/project/venv/lib/python3.11/site-packages/keras/src/models/functional.py:561, in functional_from_config(cls, config, custom_objects)
#     559 # First, we create all layers and enqueue nodes to be processed
#     560 for layer_data in functional_config["layers"]:
# --> 561     process_layer(layer_data)
#     563 # Then we process nodes in order of layer depth.
#     564 # Nodes that cannot yet be processed (if the inbound node
#     565 # does not yet exist) are re-enqueued, and the process
#     566 # is repeated until all nodes are processed.
#     567 while unprocessed_nodes:
#
# File ~/project/venv/lib/python3.11/site-packages/keras/src/models/functional.py:524, in functional_from_config.<locals>.process_layer(layer_data)
#     520 # Instantiate layer.
#     521 if "module" not in layer_data:
#     522     # Legacy format deserialization (no "module" key)
#     523     # used for H5 and SavedModel formats
# --> 524     layer = saving_utils.model_from_config(
#     525         layer_data, custom_objects=custom_objects
#     526     )
#     527 else:
#     528     layer = serialization_lib.deserialize_keras_object(
#     529         layer_data, custom_objects=custom_objects
#     530     )
#
# File ~/project/venv/lib/python3.11/site-packages/keras/src/legacy/saving/saving_utils.py:83, in model_from_config(config, custom_objects)
#      80         function_dict["config"]["closure"] = function_config[2]
#      81         config["config"]["function"] = function_dict
# ---> 83 return serialization.deserialize_keras_object(
#      84     config,
#      85     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      86     custom_objects=custom_objects,
#      87     printable_module_name="layer",
#      88 )
#
# File ~/project/venv/lib/python3.11/site-packages/keras/src/legacy/saving/serialization.py:497, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     495     else:
#     496         with object_registration.CustomObjectScope(custom_objects):
# --> 497             deserialized_obj = cls.from_config(cls_config)
#     498 else:
#     499     # Then `cls` may be a function returning a class.
#     500     # in this case by convention `config` holds
#     501     # the kwargs of the function.
#     502     custom_objects = custom_objects or {}
#
# File ~/project/venv/lib/python3.11/site-packages/keras/src/layers/rnn/lstm.py:692, in LSTM.from_config(cls, config)
#     690 @classmethod
#     691 def from_config(cls, config):
# --> 692     return cls(**config)
#
# File ~/project/venv/lib/python3.11/site-packages/keras/src/layers/rnn/lstm.py:499, in LSTM.__init__(self, units, activation, recurrent_activation, use_bias, kernel_initializer, recurrent_initializer, bias_initializer, unit_forget_bias, kernel_regularizer, recurrent_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, recurrent_constraint, bias_constraint, dropout, recurrent_dropout, seed, return_sequences, return_state, go_backwards, stateful, unroll, use_cudnn, **kwargs)
#     448 def __init__(
#     449     self,
#     450     units,
#    (...)    474     **kwargs,
#     475 ):
#     476     cell = LSTMCell(
#     477         units,
#     478         activation=activation,
#    (...)    497         implementation=kwargs.pop("implementation", 2),
#     498     )
# --> 499     super().__init__(
#     500         cell,
#     501         return_sequences=return_sequences,
#     502         return_state=return_state,
#     503         go_backwards=go_backwards,
#     504         stateful=stateful,
#     505         unroll=unroll,
#     506         activity_regularizer=activity_regularizer,
#     507         **kwargs,
#     508     )
#     509     self.input_spec = InputSpec(ndim=3)
#     510     if use_cudnn not in ("auto", True, False):
#
# File ~/project/venv/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:199, in RNN.__init__(self, cell, return_sequences, return_state, go_backwards, stateful, unroll, zero_output_for_mask, **kwargs)
#     192 if "state_size" not in dir(cell):
#     193     raise ValueError(
#     194         "The RNN cell should have a `state_size` attribute "
#     195         "(single integer or list of integers, "
#     196         "one integer per RNN state). "
#     197         f"Received: cell={cell}"
#     198     )
# --> 199 super().__init__(**kwargs)
#     201 # If True, the output for masked timestep will be zeros, whereas in the
#     202 # False case, output from previous timestep is returned for masked
#     203 # timestep.
#     204 self.zero_output_for_mask = zero_output_for_mask
#
# File ~/project/venv/lib/python3.11/site-packages/keras/src/layers/layer.py:294, in Layer.__init__(self, activity_regularizer, trainable, dtype, autocast, name, **kwargs)
#     292     self._input_shape_arg = input_shape_arg
#     293 if kwargs:
# --> 294     raise ValueError(
#     295         "Unrecognized keyword arguments "
#     296         f"passed to {self.__class__.__name__}: {kwargs}"
#     297     )
#     299 self._path = None  # Will be determined in `build_wrapper`
#     300 self.built = False
#
# ValueError: Unrecognized keyword arguments passed to LSTM: {'time_major': False}

# %%
# Get the InceptionV3 model trained on imagenet data
model_temp = InceptionV3(weights='imagenet',input_shape=(299,299,3))
# Remove the last layer (output softmax layer) from the inception v3
model_inception = Model(model_temp.input, model_temp.layers[-2].output)
model_inception.make_predict_function()

# %%
def preprocess_image(img):
    # Convert all the images to size 299x299 as expected by the
    # inception v3 model
    img = image.load_img(img, target_size=(299, 299))
    # Convert PIL image to numpy array of 3-dimensions
    x = image.img_to_array(img)
    # Add one more dimension
    x = np.expand_dims(x, axis=0)
    # preprocess images using preprocess_input() from inception module
    x = preprocess_input(x)
    return x

# %%
def encode_image(img):
    img = preprocess_image(img)
    feature_vector = model_inception.predict(img)
    # reshape from (1, 2048) to (2048, )
    feature_vector = feature_vector.reshape(1, feature_vector.shape[1])
    return feature_vector

# %%
with open("Storage/word_to_idx.pkl", 'rb') as w2i:
    word_to_idx = pickle.load(w2i)
    
with open("Storage/idx_to_word.pkl", 'rb') as i2w:
    idx_to_word = pickle.load(i2w)

# %%
def beam_search(image, beam_index = 5):
    start = [word_to_idx["startseq"]]
    max_length = 74
    # start_word[0][0] = index of the starting word
    # start_word[0][1] = probability of the word predicted
    start_word = [[start, 0.0]]
    
    while len(start_word[0][0]) < max_length:
        temp = []
        for s in start_word:
            par_caps = pad_sequences([s[0]], maxlen=max_length)
            e = image
            preds = model.predict([e, np.array(par_caps)])
            
            # Getting the top <beam_index>(n) predictions
            word_preds = np.argsort(preds[0])[-beam_index:]
            
            # creating a new list so as to put them via the model again
            for w in word_preds:
                next_cap, prob = s[0][:], s[1]
                next_cap.append(w)
                prob += preds[0][w]
                temp.append([next_cap, prob])
                    
        start_word = temp
        # Sorting according to the probabilities
        start_word = sorted(start_word, reverse=False, key=lambda l: l[1])
        # Getting the top words
        start_word = start_word[-beam_index:]
    
    start_word = start_word[-1][0]
    intermediate_caption = [idx_to_word[i] for i in start_word]

    final_caption = []
    
    for i in intermediate_caption:
        if i != 'endseq':
            final_caption.append(i)
        else:
            break
    
    final_caption = ' '.join(final_caption[1:])
    return final_caption

# %%
def caption_this_image(image):
    enc = encode_image(image)
    caption = beam_search(enc)
    return caption

# %%
def voice(myText):

    # Language we want to use 
    language = 'en'

    output = gTTS(text=myText, lang=language, slow=False)
    t=time.time()
    nm="output"+str(t)+".mp3"
    output.save(nm)
    playsound(nm)

# %%
def output_caption_stream(image):
    nm = "frame.jpg"
    cv2.imwrite(nm, image)
    #print(caption_this_image(nm))
    voice(caption_this_image(nm))
